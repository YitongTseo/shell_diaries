# %%
# !pip install pdfplumber
# Out:
# Requirement already satisfied: pdfplumber in /opt/miniconda3/envs/radial_faces_env/lib/python3.8/site-packages (0.11.5)
# Requirement already satisfied: pdfminer.six==20231228 in /opt/miniconda3/envs/radial_faces_env/lib/python3.8/site-packages (from pdfplumber) (20231228)
# Requirement already satisfied: Pillow>=9.1 in /opt/miniconda3/envs/radial_faces_env/lib/python3.8/site-packages (from pdfplumber) (10.2.0)
# Requirement already satisfied: pypdfium2>=4.18.0 in /opt/miniconda3/envs/radial_faces_env/lib/python3.8/site-packages (from pdfplumber) (4.30.0)
# Requirement already satisfied: charset-normalizer>=2.0.0 in /opt/miniconda3/envs/radial_faces_env/lib/python3.8/site-packages (from pdfminer.six==20231228->pdfplumber) (3.4.3)
# Requirement already satisfied: cryptography>=36.0.0 in /opt/miniconda3/envs/radial_faces_env/lib/python3.8/site-packages (from pdfminer.six==20231228->pdfplumber) (46.0.2)
# Requirement already satisfied: cffi>=1.14 in /opt/miniconda3/envs/radial_faces_env/lib/python3.8/site-packages (from cryptography>=36.0.0->pdfminer.six==20231228->pdfplumber) (1.17.1)
# Requirement already satisfied: typing-extensions>=4.13.2 in /opt/miniconda3/envs/radial_faces_env/lib/python3.8/site-packages (from cryptography>=36.0.0->pdfminer.six==20231228->pdfplumber) (4.13.2)
# Requirement already satisfied: pycparser in /opt/miniconda3/envs/radial_faces_env/lib/python3.8/site-packages (from cffi>=1.14->cryptography>=36.0.0->pdfminer.six==20231228->pdfplumber) (2.23)

# %%
import pandas as pd
import re
import pdfplumber

def extract_chromatogram_peaks(text):
    """
    Extract chromatogram peak data from PDF text.
    
    Parameters:
    -----------
    text : str
        Full text from PDF
        
    Returns:
    --------
    pd.DataFrame
        DataFrame with Peak, Start, RT, End, Height, Area, Area%, SNR
    """
    peaks = []
    lines = text.split('\n')
    
    in_peak_section = False
    
    for line in lines:
        if "Chromatogram Peaks" in line:
            in_peak_section = True
            continue
        
        if in_peak_section:
            # Match peak data: Peak Start RT End Height Area Area% SNR
            match = re.match(
                r'^(\d+)\s+([\d.]+)\s+([\d.]+)\s+([\d.]+)\s+'
                r'([\d.]+)\s+([\d.]+)\s+([\d.]+)',
                line
            )
            
            if match:
                peaks.append({
                    'Peak': int(match.group(1)),
                    'Peak_Start': float(match.group(2)),
                    'Peak_RT': float(match.group(3)),
                    'Peak_End': float(match.group(4)),
                    'Height': float(match.group(5)),
                    'Area': float(match.group(6)),
                    'Area_Pct': float(match.group(7))
                })
            
            # Stop when we hit another section
            elif line.strip() and peaks and not line.startswith('Peak'):
                if 'Sample Spectra' in line or 'Spectrum Peaks' in line:
                    break
    
    return pd.DataFrame(peaks)


def match_compounds_to_peaks(compounds_df, peaks_df, rt_tolerance=0.0001):
    """
    Match compounds to chromatogram peaks based on RT values.
    
    Parameters:
    -----------
    compounds_df : pd.DataFrame
        Compounds dataframe
    peaks_df : pd.DataFrame
        Chromatogram peaks dataframe
    rt_tolerance : float
        RT tolerance for matching in minutes (default 0.5 min)
        
    Returns:
    --------
    pd.DataFrame
        Compounds with matched area data
    """
    compounds_with_area = compounds_df.copy()
    compounds_with_area['Area'] = None
    compounds_with_area['Area_Pct'] = None
    compounds_with_area['Peak_Height'] = None
    
    for idx, compound in compounds_with_area.iterrows():
        compound_rt = compound['RT']
        
        # Find peaks within RT tolerance
        matching_peaks = peaks_df[
            (peaks_df['Peak_RT'] >= compound_rt - rt_tolerance) &
            (peaks_df['Peak_RT'] <= compound_rt + rt_tolerance)
        ]
        
        if len(matching_peaks) > 0:
            # If multiple matches, take the closest one
            matching_peaks['RT_Diff'] = abs(matching_peaks['Peak_RT'] - compound_rt)
            best_match = matching_peaks.loc[matching_peaks['RT_Diff'].idxmin()]
            
            compounds_with_area.at[idx, 'Area'] = best_match['Area']
            compounds_with_area.at[idx, 'Area_Pct'] = best_match['Area_Pct']
            compounds_with_area.at[idx, 'Peak_Height'] = best_match['Height']
    
    return compounds_with_area


def extract_compound_summary(pdf_path, rt_tolerance=0.0001):
    """
    Extract Compound Summary table from MassHunter Analysis Report PDF
    and cross-reference with chromatogram peak areas.
    
    Parameters:
    -----------
    pdf_path : str
        Path to the PDF file
    rt_tolerance : float
        RT tolerance for matching compounds to peaks (minutes)
        
    Returns:
    --------
    pd.DataFrame
        DataFrame containing compound data with matched peak areas
    """
    
    with pdfplumber.open(pdf_path) as pdf:
        full_text = ""
        compounds = []
        
        for page in pdf.pages:
            text = page.extract_text()
            full_text += text + "\n"
            
            # Find the Compound Summary section
            if "Compound Summary" in text:
                lines = text.split('\n')
                
                # Find where compound data starts
                start_idx = None
                for i, line in enumerate(lines):
                    if re.match(r'^\d+\s+C\d+\s+H\d+', line):
                        start_idx = i
                        break
                
                if start_idx:
                    # Parse each compound line
                    for line in lines[start_idx:]:
                        # Match pattern: number, formula, RT, Mass, optional CAS, Source, Scores
                        match = re.match(
                            r'^(\d+)\s+(C\d+\s+H\d+(?:\s+[A-Z][a-z]?\d*)*)\s+'
                            r'([\d.]+)\s+([\d.]+)\s+'
                            r'(?:([\d-]+)\s+)?'  # Optional CAS ID
                            r'(\w+)\s+([\d.]+)\s+(\w+)',
                            line
                        )
                        
                        if match:
                            cpd_num = int(match.group(1))
                            formula = match.group(2).replace(' ', '')
                            rt = float(match.group(3))
                            mass = float(match.group(4))
                            cas_id = match.group(5) if match.group(5) else None
                            source = match.group(6)
                            score = float(match.group(7))
                            algorithm = match.group(8)
                            
                            compounds.append({
                                'Cpd': cpd_num,
                                'Formula': formula,
                                'RT': rt,
                                'Mass': mass,
                                'CAS_ID': cas_id,
                                'Source': source,
                                'Score': score,
                                'Algorithm': algorithm
                            })
    
    compounds_df = pd.DataFrame(compounds)
    
    # Extract chromatogram peaks
    peaks_df = extract_chromatogram_peaks(full_text)
    
    # Match compounds to peaks
    if len(peaks_df) > 0:
        compounds_with_area = match_compounds_to_peaks(
            compounds_df, peaks_df, rt_tolerance
        )
        
        print(f"Extracted {len(compounds_df)} compounds")
        print(f"Found {len(peaks_df)} chromatogram peaks")
        print(f"Matched {compounds_with_area['Area'].notna().sum()} compounds to peaks")
        
        return compounds_with_area
    else:
        print(f"Warning: No chromatogram peaks found in {pdf_path}")
        compounds_df['Area'] = None
        compounds_df['Area_Pct'] = None
        compounds_df['Peak_Height'] = None
        return compounds_df

# %%
import pandas as pd
from pathlib import Path

# Assuming you have extract_compound_summary defined/imported
# e.g., from your_module import extract_compound_summary

# Path to the folder containing PDFs (including subdirectories)
pdf_folder = Path('/Users/yitong/Documents/GitHub/shell_diaries/TRYING_OUT_MS_RESULTS')  

# Find all PDF files recursively in the folder
pdf_files = list(pdf_folder.rglob('*.pdf'))

all_in_one_place = []

# Loop through each PDF file
for pdf_file in pdf_files:
    print(f"\nProcessing {pdf_file}...")
    
    # Extract compound summary
    df = extract_compound_summary(str(pdf_file))
    
    # Display some results
    print(df.head(10))
    print(f"Total compounds extracted: {len(df)}")
    
    print("\nFormula value counts:")
    print(df['Formula'].value_counts().head())
    
    print("\nRT statistics:")
    print(df['RT'].describe())
    
    # Filter for rows with peak area
    has_peak_df = df[~df['Area'].isna()]
    has_peak_df_sorted = has_peak_df.sort_values(by='Area_Pct', ascending=False)
    print(f"After filtering for areas : {len(has_peak_df)}")
    print(has_peak_df_sorted.head())

    all_in_one_place.append((pdf_file, df, has_peak_df_sorted))
# Out:
# Processing /Users/yitong/Documents/GitHub/shell_diaries/TRYING_OUT_MS_RESULTS/70425_shell2_Analysis.pdf...
# /var/folders/1j/7hbmv0v92x141ltlqxmr9dzw0000gn/T/ipykernel_48438/2042415455.py:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matching_peaks['RT_Diff'] = abs(matching_peaks['Peak_RT'] - compound_rt)
# /var/folders/1j/7hbmv0v92x141ltlqxmr9dzw0000gn/T/ipykernel_48438/2042415455.py:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matching_peaks['RT_Diff'] = abs(matching_peaks['Peak_RT'] - compound_rt)
# /var/folders/1j/7hbmv0v92x141ltlqxmr9dzw0000gn/T/ipykernel_48438/2042415455.py:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matching_peaks['RT_Diff'] = abs(matching_peaks['Peak_RT'] - compound_rt)
# /var/folders/1j/7hbmv0v92x141ltlqxmr9dzw0000gn/T/ipykernel_48438/2042415455.py:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matching_peaks['RT_Diff'] = abs(matching_peaks['Peak_RT'] - compound_rt)
# /var/folders/1j/7hbmv0v92x141ltlqxmr9dzw0000gn/T/ipykernel_48438/2042415455.py:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matching_peaks['RT_Diff'] = abs(matching_peaks['Peak_RT'] - compound_rt)
# /var/folders/1j/7hbmv0v92x141ltlqxmr9dzw0000gn/T/ipykernel_48438/2042415455.py:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matching_peaks['RT_Diff'] = abs(matching_peaks['Peak_RT'] - compound_rt)
# /var/folders/1j/7hbmv0v92x141ltlqxmr9dzw0000gn/T/ipykernel_48438/2042415455.py:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matching_peaks['RT_Diff'] = abs(matching_peaks['Peak_RT'] - compound_rt)
# /var/folders/1j/7hbmv0v92x141ltlqxmr9dzw0000gn/T/ipykernel_48438/2042415455.py:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matching_peaks['RT_Diff'] = abs(matching_peaks['Peak_RT'] - compound_rt)
# /var/folders/1j/7hbmv0v92x141ltlqxmr9dzw0000gn/T/ipykernel_48438/2042415455.py:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matching_peaks['RT_Diff'] = abs(matching_peaks['Peak_RT'] - compound_rt)
# /var/folders/1j/7hbmv0v92x141ltlqxmr9dzw0000gn/T/ipykernel_48438/2042415455.py:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matching_peaks['RT_Diff'] = abs(matching_peaks['Peak_RT'] - compound_rt)
# /var/folders/1j/7hbmv0v92x141ltlqxmr9dzw0000gn/T/ipykernel_48438/2042415455.py:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matching_peaks['RT_Diff'] = abs(matching_peaks['Peak_RT'] - compound_rt)
# /var/folders/1j/7hbmv0v92x141ltlqxmr9dzw0000gn/T/ipykernel_48438/2042415455.py:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matching_peaks['RT_Diff'] = abs(matching_peaks['Peak_RT'] - compound_rt)
# /var/folders/1j/7hbmv0v92x141ltlqxmr9dzw0000gn/T/ipykernel_48438/2042415455.py:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matching_peaks['RT_Diff'] = abs(matching_peaks['Peak_RT'] - compound_rt)
# /var/folders/1j/7hbmv0v92x141ltlqxmr9dzw0000gn/T/ipykernel_48438/2042415455.py:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matching_peaks['RT_Diff'] = abs(matching_peaks['Peak_RT'] - compound_rt)
# Extracted 78 compounds
# Found 47 chromatogram peaks
# Matched 14 compounds to peaks
#    Cpd     Formula      RT      Mass CAS_ID Source  Score Algorithm  \
# 0    1  C22H20N2O7   7.270  424.1280   None    FBF  81.73       FBF
# 1    2   C21H21NO6   9.921  383.1337   None    FBF  59.97       FBF
# 2    3  C20H24N2O2   4.307  324.1822   None    FBF  57.62       FBF
# 3    4   C21H23NO5   7.841  369.1596   None    FBF  87.44       FBF
# 4    5    C10H15NO   0.384  165.1149   None    FBF  78.64       FBF
# 5    6  C21H24N2O2   7.062  336.1817   None    FBF  55.11       FBF
# 6    7    C18H20N2   0.436  264.1634   None    FBF  77.75       FBF
# 7    8   C12H16N2O   7.945  204.1268   None    FBF  51.72       FBF
# 8    9    C26H44N2  13.456  384.3498   None    FBF  61.71       FBF
# 9   10   C18H35NO2   6.516  297.2664   None    FBF  98.96       FBF
#
#          Area Area_Pct Peak_Height
# 0   4167504.0     1.52    891900.0
# 1        None     None        None
# 2        None     None        None
# 3        None     None        None
# 4        None     None        None
# 5        None     None        None
# 6  91227911.0    33.38   8845431.0
# 7        None     None        None
# 8        None     None        None
# 9        None     None        None
# Total compounds extracted: 78
#
# Formula value counts:
# Formula
# C22H20N2O7    1
# C14H16N4      1
# C8H17NO5      1
# C6H12N2O2     1
# C19H21N3O     1
# Name: count, dtype: int64
#
# RT statistics:
# count    78.000000
# mean      7.055654
# std       5.198882
# min       0.358000
# 25%       3.170250
# 50%       7.140000
# 75%       9.563500
# max      21.407000
# Name: RT, dtype: float64
# After filtering for areas : 14
#     Cpd       Formula     RT      Mass CAS_ID Source  Score Algorithm  \
# 11   12    C23H30N2O4  3.086  398.2234   None    FBF  68.70       FBF
# 64   65    C25H31N3O4  3.086  437.2323   None    FBF  89.84       FBF
# 6     7      C18H20N2  0.436  264.1634   None    FBF  77.75       FBF
# 29   30  C15H10ClFN2O  0.436  288.0485   None    FBF  53.66       FBF
# 52   53      C6H9N3O4  0.436  187.0577   None    FBF  66.06       FBF
#
#           Area Area_Pct Peak_Height
# 11  93285152.0    34.13   6685912.0
# 64  93285152.0    34.13   6685912.0
# 6   91227911.0    33.38   8845431.0
# 29  91227911.0    33.38   8845431.0
# 52  91227911.0    33.38   8845431.0
#
# Processing /Users/yitong/Documents/GitHub/shell_diaries/TRYING_OUT_MS_RESULTS/70425_shell5_Analysis.pdf...
# Warning: No chromatogram peaks found in /Users/yitong/Documents/GitHub/shell_diaries/TRYING_OUT_MS_RESULTS/70425_shell5_Analysis.pdf
#    Cpd     Formula      RT      Mass CAS_ID Source  Score Algorithm  Area  \
# 0    1  C20H24N2O2  10.977  324.1865   None    FBF  52.08       FBF  None
# 1    2  C20H26N2O2  16.799  326.1963   None    FBF  77.35       FBF  None
# 2    3   C21H23NO5   7.833  369.1601   None    FBF  68.24       FBF  None
# 3    4   C14H8N2O2   0.926  236.0609   None    FBF  68.11       FBF  None
# 4    5  C21H24N2O2  22.254  336.1836   None    FBF  62.41       FBF  None
# 5    6  C15H22N2O2  15.292  262.1684   None    FBF  52.34       FBF  None
# 6    7   C20H29NO2  18.435  315.2190   None    FBF  52.21       FBF  None
# 7    8   C18H35NO2   6.560  297.2652   None    FBF  88.62       FBF  None
# 8    9      C8H17N  16.825  127.1360   None    FBF  82.83       FBF  None
# 9   10  C23H30N2O4  21.969  398.2211   None    FBF  75.23       FBF  None
#
#   Area_Pct Peak_Height
# 0     None        None
# 1     None        None
# 2     None        None
# 3     None        None
# 4     None        None
# 5     None        None
# 6     None        None
# 7     None        None
# 8     None        None
# 9     None        None
# Total compounds extracted: 5013
#
# Formula value counts:
# Formula
# C12H15NO3       2
# C8H13N3O        2
# C9H15NO5        2
# C9H17N3O4       2
# C58H114NO11P    1
# Name: count, dtype: int64
#
# RT statistics:
# count    5013.000000
# mean       16.161715
# std         4.801926
# min         0.329000
# 25%        13.836000
# 50%        17.578000
# 75%        19.527000
# max        22.955000
# Name: RT, dtype: float64
# After filtering for areas : 0
# Empty DataFrame
# Columns: [Cpd, Formula, RT, Mass, CAS_ID, Source, Score, Algorithm, Area, Area_Pct, Peak_Height]
# Index: []
#
# Processing /Users/yitong/Documents/GitHub/shell_diaries/TRYING_OUT_MS_RESULTS/63025_shell10_Analysis (1).pdf...
# /var/folders/1j/7hbmv0v92x141ltlqxmr9dzw0000gn/T/ipykernel_48438/2042415455.py:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matching_peaks['RT_Diff'] = abs(matching_peaks['Peak_RT'] - compound_rt)
# /var/folders/1j/7hbmv0v92x141ltlqxmr9dzw0000gn/T/ipykernel_48438/2042415455.py:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matching_peaks['RT_Diff'] = abs(matching_peaks['Peak_RT'] - compound_rt)
# /var/folders/1j/7hbmv0v92x141ltlqxmr9dzw0000gn/T/ipykernel_48438/2042415455.py:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matching_peaks['RT_Diff'] = abs(matching_peaks['Peak_RT'] - compound_rt)
# /var/folders/1j/7hbmv0v92x141ltlqxmr9dzw0000gn/T/ipykernel_48438/2042415455.py:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matching_peaks['RT_Diff'] = abs(matching_peaks['Peak_RT'] - compound_rt)
# /var/folders/1j/7hbmv0v92x141ltlqxmr9dzw0000gn/T/ipykernel_48438/2042415455.py:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matching_peaks['RT_Diff'] = abs(matching_peaks['Peak_RT'] - compound_rt)
# /var/folders/1j/7hbmv0v92x141ltlqxmr9dzw0000gn/T/ipykernel_48438/2042415455.py:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matching_peaks['RT_Diff'] = abs(matching_peaks['Peak_RT'] - compound_rt)
# /var/folders/1j/7hbmv0v92x141ltlqxmr9dzw0000gn/T/ipykernel_48438/2042415455.py:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matching_peaks['RT_Diff'] = abs(matching_peaks['Peak_RT'] - compound_rt)
# /var/folders/1j/7hbmv0v92x141ltlqxmr9dzw0000gn/T/ipykernel_48438/2042415455.py:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matching_peaks['RT_Diff'] = abs(matching_peaks['Peak_RT'] - compound_rt)
# /var/folders/1j/7hbmv0v92x141ltlqxmr9dzw0000gn/T/ipykernel_48438/2042415455.py:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matching_peaks['RT_Diff'] = abs(matching_peaks['Peak_RT'] - compound_rt)
# /var/folders/1j/7hbmv0v92x141ltlqxmr9dzw0000gn/T/ipykernel_48438/2042415455.py:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matching_peaks['RT_Diff'] = abs(matching_peaks['Peak_RT'] - compound_rt)
# /var/folders/1j/7hbmv0v92x141ltlqxmr9dzw0000gn/T/ipykernel_48438/2042415455.py:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matching_peaks['RT_Diff'] = abs(matching_peaks['Peak_RT'] - compound_rt)
# /var/folders/1j/7hbmv0v92x141ltlqxmr9dzw0000gn/T/ipykernel_48438/2042415455.py:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matching_peaks['RT_Diff'] = abs(matching_peaks['Peak_RT'] - compound_rt)
# /var/folders/1j/7hbmv0v92x141ltlqxmr9dzw0000gn/T/ipykernel_48438/2042415455.py:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matching_peaks['RT_Diff'] = abs(matching_peaks['Peak_RT'] - compound_rt)
# /var/folders/1j/7hbmv0v92x141ltlqxmr9dzw0000gn/T/ipykernel_48438/2042415455.py:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matching_peaks['RT_Diff'] = abs(matching_peaks['Peak_RT'] - compound_rt)
# /var/folders/1j/7hbmv0v92x141ltlqxmr9dzw0000gn/T/ipykernel_48438/2042415455.py:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matching_peaks['RT_Diff'] = abs(matching_peaks['Peak_RT'] - compound_rt)
# /var/folders/1j/7hbmv0v92x141ltlqxmr9dzw0000gn/T/ipykernel_48438/2042415455.py:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matching_peaks['RT_Diff'] = abs(matching_peaks['Peak_RT'] - compound_rt)
# /var/folders/1j/7hbmv0v92x141ltlqxmr9dzw0000gn/T/ipykernel_48438/2042415455.py:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matching_peaks['RT_Diff'] = abs(matching_peaks['Peak_RT'] - compound_rt)
# /var/folders/1j/7hbmv0v92x141ltlqxmr9dzw0000gn/T/ipykernel_48438/2042415455.py:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matching_peaks['RT_Diff'] = abs(matching_peaks['Peak_RT'] - compound_rt)
# /var/folders/1j/7hbmv0v92x141ltlqxmr9dzw0000gn/T/ipykernel_48438/2042415455.py:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matching_peaks['RT_Diff'] = abs(matching_peaks['Peak_RT'] - compound_rt)
# /var/folders/1j/7hbmv0v92x141ltlqxmr9dzw0000gn/T/ipykernel_48438/2042415455.py:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matching_peaks['RT_Diff'] = abs(matching_peaks['Peak_RT'] - compound_rt)
# /var/folders/1j/7hbmv0v92x141ltlqxmr9dzw0000gn/T/ipykernel_48438/2042415455.py:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matching_peaks['RT_Diff'] = abs(matching_peaks['Peak_RT'] - compound_rt)
# /var/folders/1j/7hbmv0v92x141ltlqxmr9dzw0000gn/T/ipykernel_48438/2042415455.py:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matching_peaks['RT_Diff'] = abs(matching_peaks['Peak_RT'] - compound_rt)
# /var/folders/1j/7hbmv0v92x141ltlqxmr9dzw0000gn/T/ipykernel_48438/2042415455.py:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matching_peaks['RT_Diff'] = abs(matching_peaks['Peak_RT'] - compound_rt)
# /var/folders/1j/7hbmv0v92x141ltlqxmr9dzw0000gn/T/ipykernel_48438/2042415455.py:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matching_peaks['RT_Diff'] = abs(matching_peaks['Peak_RT'] - compound_rt)
# /var/folders/1j/7hbmv0v92x141ltlqxmr9dzw0000gn/T/ipykernel_48438/2042415455.py:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matching_peaks['RT_Diff'] = abs(matching_peaks['Peak_RT'] - compound_rt)
# /var/folders/1j/7hbmv0v92x141ltlqxmr9dzw0000gn/T/ipykernel_48438/2042415455.py:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matching_peaks['RT_Diff'] = abs(matching_peaks['Peak_RT'] - compound_rt)
# /var/folders/1j/7hbmv0v92x141ltlqxmr9dzw0000gn/T/ipykernel_48438/2042415455.py:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matching_peaks['RT_Diff'] = abs(matching_peaks['Peak_RT'] - compound_rt)
# /var/folders/1j/7hbmv0v92x141ltlqxmr9dzw0000gn/T/ipykernel_48438/2042415455.py:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matching_peaks['RT_Diff'] = abs(matching_peaks['Peak_RT'] - compound_rt)
# /var/folders/1j/7hbmv0v92x141ltlqxmr9dzw0000gn/T/ipykernel_48438/2042415455.py:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matching_peaks['RT_Diff'] = abs(matching_peaks['Peak_RT'] - compound_rt)
# /var/folders/1j/7hbmv0v92x141ltlqxmr9dzw0000gn/T/ipykernel_48438/2042415455.py:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matching_peaks['RT_Diff'] = abs(matching_peaks['Peak_RT'] - compound_rt)
# /var/folders/1j/7hbmv0v92x141ltlqxmr9dzw0000gn/T/ipykernel_48438/2042415455.py:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matching_peaks['RT_Diff'] = abs(matching_peaks['Peak_RT'] - compound_rt)
# /var/folders/1j/7hbmv0v92x141ltlqxmr9dzw0000gn/T/ipykernel_48438/2042415455.py:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matching_peaks['RT_Diff'] = abs(matching_peaks['Peak_RT'] - compound_rt)
# /var/folders/1j/7hbmv0v92x141ltlqxmr9dzw0000gn/T/ipykernel_48438/2042415455.py:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matching_peaks['RT_Diff'] = abs(matching_peaks['Peak_RT'] - compound_rt)
# /var/folders/1j/7hbmv0v92x141ltlqxmr9dzw0000gn/T/ipykernel_48438/2042415455.py:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matching_peaks['RT_Diff'] = abs(matching_peaks['Peak_RT'] - compound_rt)
# /var/folders/1j/7hbmv0v92x141ltlqxmr9dzw0000gn/T/ipykernel_48438/2042415455.py:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matching_peaks['RT_Diff'] = abs(matching_peaks['Peak_RT'] - compound_rt)
# /var/folders/1j/7hbmv0v92x141ltlqxmr9dzw0000gn/T/ipykernel_48438/2042415455.py:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matching_peaks['RT_Diff'] = abs(matching_peaks['Peak_RT'] - compound_rt)
# /var/folders/1j/7hbmv0v92x141ltlqxmr9dzw0000gn/T/ipykernel_48438/2042415455.py:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matching_peaks['RT_Diff'] = abs(matching_peaks['Peak_RT'] - compound_rt)
# /var/folders/1j/7hbmv0v92x141ltlqxmr9dzw0000gn/T/ipykernel_48438/2042415455.py:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matching_peaks['RT_Diff'] = abs(matching_peaks['Peak_RT'] - compound_rt)
# /var/folders/1j/7hbmv0v92x141ltlqxmr9dzw0000gn/T/ipykernel_48438/2042415455.py:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matching_peaks['RT_Diff'] = abs(matching_peaks['Peak_RT'] - compound_rt)
# /var/folders/1j/7hbmv0v92x141ltlqxmr9dzw0000gn/T/ipykernel_48438/2042415455.py:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matching_peaks['RT_Diff'] = abs(matching_peaks['Peak_RT'] - compound_rt)
# /var/folders/1j/7hbmv0v92x141ltlqxmr9dzw0000gn/T/ipykernel_48438/2042415455.py:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matching_peaks['RT_Diff'] = abs(matching_peaks['Peak_RT'] - compound_rt)
# /var/folders/1j/7hbmv0v92x141ltlqxmr9dzw0000gn/T/ipykernel_48438/2042415455.py:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matching_peaks['RT_Diff'] = abs(matching_peaks['Peak_RT'] - compound_rt)
# /var/folders/1j/7hbmv0v92x141ltlqxmr9dzw0000gn/T/ipykernel_48438/2042415455.py:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matching_peaks['RT_Diff'] = abs(matching_peaks['Peak_RT'] - compound_rt)
# /var/folders/1j/7hbmv0v92x141ltlqxmr9dzw0000gn/T/ipykernel_48438/2042415455.py:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matching_peaks['RT_Diff'] = abs(matching_peaks['Peak_RT'] - compound_rt)
# /var/folders/1j/7hbmv0v92x141ltlqxmr9dzw0000gn/T/ipykernel_48438/2042415455.py:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matching_peaks['RT_Diff'] = abs(matching_peaks['Peak_RT'] - compound_rt)
# /var/folders/1j/7hbmv0v92x141ltlqxmr9dzw0000gn/T/ipykernel_48438/2042415455.py:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matching_peaks['RT_Diff'] = abs(matching_peaks['Peak_RT'] - compound_rt)
# /var/folders/1j/7hbmv0v92x141ltlqxmr9dzw0000gn/T/ipykernel_48438/2042415455.py:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matching_peaks['RT_Diff'] = abs(matching_peaks['Peak_RT'] - compound_rt)
# /var/folders/1j/7hbmv0v92x141ltlqxmr9dzw0000gn/T/ipykernel_48438/2042415455.py:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matching_peaks['RT_Diff'] = abs(matching_peaks['Peak_RT'] - compound_rt)
# /var/folders/1j/7hbmv0v92x141ltlqxmr9dzw0000gn/T/ipykernel_48438/2042415455.py:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matching_peaks['RT_Diff'] = abs(matching_peaks['Peak_RT'] - compound_rt)
# /var/folders/1j/7hbmv0v92x141ltlqxmr9dzw0000gn/T/ipykernel_48438/2042415455.py:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matching_peaks['RT_Diff'] = abs(matching_peaks['Peak_RT'] - compound_rt)
# /var/folders/1j/7hbmv0v92x141ltlqxmr9dzw0000gn/T/ipykernel_48438/2042415455.py:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matching_peaks['RT_Diff'] = abs(matching_peaks['Peak_RT'] - compound_rt)
# /var/folders/1j/7hbmv0v92x141ltlqxmr9dzw0000gn/T/ipykernel_48438/2042415455.py:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matching_peaks['RT_Diff'] = abs(matching_peaks['Peak_RT'] - compound_rt)
# /var/folders/1j/7hbmv0v92x141ltlqxmr9dzw0000gn/T/ipykernel_48438/2042415455.py:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matching_peaks['RT_Diff'] = abs(matching_peaks['Peak_RT'] - compound_rt)
# /var/folders/1j/7hbmv0v92x141ltlqxmr9dzw0000gn/T/ipykernel_48438/2042415455.py:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matching_peaks['RT_Diff'] = abs(matching_peaks['Peak_RT'] - compound_rt)
# /var/folders/1j/7hbmv0v92x141ltlqxmr9dzw0000gn/T/ipykernel_48438/2042415455.py:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matching_peaks['RT_Diff'] = abs(matching_peaks['Peak_RT'] - compound_rt)
# /var/folders/1j/7hbmv0v92x141ltlqxmr9dzw0000gn/T/ipykernel_48438/2042415455.py:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matching_peaks['RT_Diff'] = abs(matching_peaks['Peak_RT'] - compound_rt)
# /var/folders/1j/7hbmv0v92x141ltlqxmr9dzw0000gn/T/ipykernel_48438/2042415455.py:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matching_peaks['RT_Diff'] = abs(matching_peaks['Peak_RT'] - compound_rt)
# /var/folders/1j/7hbmv0v92x141ltlqxmr9dzw0000gn/T/ipykernel_48438/2042415455.py:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matching_peaks['RT_Diff'] = abs(matching_peaks['Peak_RT'] - compound_rt)
# /var/folders/1j/7hbmv0v92x141ltlqxmr9dzw0000gn/T/ipykernel_48438/2042415455.py:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matching_peaks['RT_Diff'] = abs(matching_peaks['Peak_RT'] - compound_rt)
# /var/folders/1j/7hbmv0v92x141ltlqxmr9dzw0000gn/T/ipykernel_48438/2042415455.py:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matching_peaks['RT_Diff'] = abs(matching_peaks['Peak_RT'] - compound_rt)
# /var/folders/1j/7hbmv0v92x141ltlqxmr9dzw0000gn/T/ipykernel_48438/2042415455.py:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matching_peaks['RT_Diff'] = abs(matching_peaks['Peak_RT'] - compound_rt)
# /var/folders/1j/7hbmv0v92x141ltlqxmr9dzw0000gn/T/ipykernel_48438/2042415455.py:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matching_peaks['RT_Diff'] = abs(matching_peaks['Peak_RT'] - compound_rt)
# /var/folders/1j/7hbmv0v92x141ltlqxmr9dzw0000gn/T/ipykernel_48438/2042415455.py:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matching_peaks['RT_Diff'] = abs(matching_peaks['Peak_RT'] - compound_rt)
# /var/folders/1j/7hbmv0v92x141ltlqxmr9dzw0000gn/T/ipykernel_48438/2042415455.py:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matching_peaks['RT_Diff'] = abs(matching_peaks['Peak_RT'] - compound_rt)
# /var/folders/1j/7hbmv0v92x141ltlqxmr9dzw0000gn/T/ipykernel_48438/2042415455.py:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matching_peaks['RT_Diff'] = abs(matching_peaks['Peak_RT'] - compound_rt)
# /var/folders/1j/7hbmv0v92x141ltlqxmr9dzw0000gn/T/ipykernel_48438/2042415455.py:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matching_peaks['RT_Diff'] = abs(matching_peaks['Peak_RT'] - compound_rt)
# /var/folders/1j/7hbmv0v92x141ltlqxmr9dzw0000gn/T/ipykernel_48438/2042415455.py:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matching_peaks['RT_Diff'] = abs(matching_peaks['Peak_RT'] - compound_rt)
# /var/folders/1j/7hbmv0v92x141ltlqxmr9dzw0000gn/T/ipykernel_48438/2042415455.py:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matching_peaks['RT_Diff'] = abs(matching_peaks['Peak_RT'] - compound_rt)
# /var/folders/1j/7hbmv0v92x141ltlqxmr9dzw0000gn/T/ipykernel_48438/2042415455.py:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matching_peaks['RT_Diff'] = abs(matching_peaks['Peak_RT'] - compound_rt)
# /var/folders/1j/7hbmv0v92x141ltlqxmr9dzw0000gn/T/ipykernel_48438/2042415455.py:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matching_peaks['RT_Diff'] = abs(matching_peaks['Peak_RT'] - compound_rt)
# /var/folders/1j/7hbmv0v92x141ltlqxmr9dzw0000gn/T/ipykernel_48438/2042415455.py:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matching_peaks['RT_Diff'] = abs(matching_peaks['Peak_RT'] - compound_rt)
# /var/folders/1j/7hbmv0v92x141ltlqxmr9dzw0000gn/T/ipykernel_48438/2042415455.py:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matching_peaks['RT_Diff'] = abs(matching_peaks['Peak_RT'] - compound_rt)
# /var/folders/1j/7hbmv0v92x141ltlqxmr9dzw0000gn/T/ipykernel_48438/2042415455.py:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matching_peaks['RT_Diff'] = abs(matching_peaks['Peak_RT'] - compound_rt)
# /var/folders/1j/7hbmv0v92x141ltlqxmr9dzw0000gn/T/ipykernel_48438/2042415455.py:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matching_peaks['RT_Diff'] = abs(matching_peaks['Peak_RT'] - compound_rt)
# /var/folders/1j/7hbmv0v92x141ltlqxmr9dzw0000gn/T/ipykernel_48438/2042415455.py:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matching_peaks['RT_Diff'] = abs(matching_peaks['Peak_RT'] - compound_rt)
# /var/folders/1j/7hbmv0v92x141ltlqxmr9dzw0000gn/T/ipykernel_48438/2042415455.py:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matching_peaks['RT_Diff'] = abs(matching_peaks['Peak_RT'] - compound_rt)
# /var/folders/1j/7hbmv0v92x141ltlqxmr9dzw0000gn/T/ipykernel_48438/2042415455.py:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matching_peaks['RT_Diff'] = abs(matching_peaks['Peak_RT'] - compound_rt)
# /var/folders/1j/7hbmv0v92x141ltlqxmr9dzw0000gn/T/ipykernel_48438/2042415455.py:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matching_peaks['RT_Diff'] = abs(matching_peaks['Peak_RT'] - compound_rt)
# /var/folders/1j/7hbmv0v92x141ltlqxmr9dzw0000gn/T/ipykernel_48438/2042415455.py:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matching_peaks['RT_Diff'] = abs(matching_peaks['Peak_RT'] - compound_rt)
# /var/folders/1j/7hbmv0v92x141ltlqxmr9dzw0000gn/T/ipykernel_48438/2042415455.py:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matching_peaks['RT_Diff'] = abs(matching_peaks['Peak_RT'] - compound_rt)
# /var/folders/1j/7hbmv0v92x141ltlqxmr9dzw0000gn/T/ipykernel_48438/2042415455.py:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matching_peaks['RT_Diff'] = abs(matching_peaks['Peak_RT'] - compound_rt)
# /var/folders/1j/7hbmv0v92x141ltlqxmr9dzw0000gn/T/ipykernel_48438/2042415455.py:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matching_peaks['RT_Diff'] = abs(matching_peaks['Peak_RT'] - compound_rt)
# /var/folders/1j/7hbmv0v92x141ltlqxmr9dzw0000gn/T/ipykernel_48438/2042415455.py:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matching_peaks['RT_Diff'] = abs(matching_peaks['Peak_RT'] - compound_rt)
# /var/folders/1j/7hbmv0v92x141ltlqxmr9dzw0000gn/T/ipykernel_48438/2042415455.py:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...
# /var/folders/1j/7hbmv0v92x141ltlqxmr9dzw0000gn/T/ipykernel_48438/2042415455.py:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matching_peaks['RT_Diff'] = abs(matching_peaks['Peak_RT'] - compound_rt)
# /var/folders/1j/7hbmv0v92x141ltlqxmr9dzw0000gn/T/ipykernel_48438/2042415455.py:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matching_peaks['RT_Diff'] = abs(matching_peaks['Peak_RT'] - compound_rt)
# /var/folders/1j/7hbmv0v92x141ltlqxmr9dzw0000gn/T/ipykernel_48438/2042415455.py:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matching_peaks['RT_Diff'] = abs(matching_peaks['Peak_RT'] - compound_rt)
# /var/folders/1j/7hbmv0v92x141ltlqxmr9dzw0000gn/T/ipykernel_48438/2042415455.py:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matching_peaks['RT_Diff'] = abs(matching_peaks['Peak_RT'] - compound_rt)
# /var/folders/1j/7hbmv0v92x141ltlqxmr9dzw0000gn/T/ipykernel_48438/2042415455.py:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matching_peaks['RT_Diff'] = abs(matching_peaks['Peak_RT'] - compound_rt)
# /var/folders/1j/7hbmv0v92x141ltlqxmr9dzw0000gn/T/ipykernel_48438/2042415455.py:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matching_peaks['RT_Diff'] = abs(matching_peaks['Peak_RT'] - compound_rt)
# /var/folders/1j/7hbmv0v92x141ltlqxmr9dzw0000gn/T/ipykernel_48438/2042415455.py:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matching_peaks['RT_Diff'] = abs(matching_peaks['Peak_RT'] - compound_rt)
# /var/folders/1j/7hbmv0v92x141ltlqxmr9dzw0000gn/T/ipykernel_48438/2042415455.py:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matching_peaks['RT_Diff'] = abs(matching_peaks['Peak_RT'] - compound_rt)
# /var/folders/1j/7hbmv0v92x141ltlqxmr9dzw0000gn/T/ipykernel_48438/2042415455.py:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matching_peaks['RT_Diff'] = abs(matching_peaks['Peak_RT'] - compound_rt)
# /var/folders/1j/7hbmv0v92x141ltlqxmr9dzw0000gn/T/ipykernel_48438/2042415455.py:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matching_peaks['RT_Diff'] = abs(matching_peaks['Peak_RT'] - compound_rt)
# /var/folders/1j/7hbmv0v92x141ltlqxmr9dzw0000gn/T/ipykernel_48438/2042415455.py:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matching_peaks['RT_Diff'] = abs(matching_peaks['Peak_RT'] - compound_rt)
# /var/folders/1j/7hbmv0v92x141ltlqxmr9dzw0000gn/T/ipykernel_48438/2042415455.py:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matching_peaks['RT_Diff'] = abs(matching_peaks['Peak_RT'] - compound_rt)
# /var/folders/1j/7hbmv0v92x141ltlqxmr9dzw0000gn/T/ipykernel_48438/2042415455.py:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matching_peaks['RT_Diff'] = abs(matching_peaks['Peak_RT'] - compound_rt)
# /var/folders/1j/7hbmv0v92x141ltlqxmr9dzw0000gn/T/ipykernel_48438/2042415455.py:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matching_peaks['RT_Diff'] = abs(matching_peaks['Peak_RT'] - compound_rt)
# /var/folders/1j/7hbmv0v92x141ltlqxmr9dzw0000gn/T/ipykernel_48438/2042415455.py:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matching_peaks['RT_Diff'] = abs(matching_peaks['Peak_RT'] - compound_rt)
# /var/folders/1j/7hbmv0v92x141ltlqxmr9dzw0000gn/T/ipykernel_48438/2042415455.py:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matching_peaks['RT_Diff'] = abs(matching_peaks['Peak_RT'] - compound_rt)
# /var/folders/1j/7hbmv0v92x141ltlqxmr9dzw0000gn/T/ipykernel_48438/2042415455.py:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matching_peaks['RT_Diff'] = abs(matching_peaks['Peak_RT'] - compound_rt)
# /var/folders/1j/7hbmv0v92x141ltlqxmr9dzw0000gn/T/ipykernel_48438/2042415455.py:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matching_peaks['RT_Diff'] = abs(matching_peaks['Peak_RT'] - compound_rt)
# /var/folders/1j/7hbmv0v92x141ltlqxmr9dzw0000gn/T/ipykernel_48438/2042415455.py:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matching_peaks['RT_Diff'] = abs(matching_peaks['Peak_RT'] - compound_rt)
# /var/folders/1j/7hbmv0v92x141ltlqxmr9dzw0000gn/T/ipykernel_48438/2042415455.py:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matching_peaks['RT_Diff'] = abs(matching_peaks['Peak_RT'] - compound_rt)
# /var/folders/1j/7hbmv0v92x141ltlqxmr9dzw0000gn/T/ipykernel_48438/2042415455.py:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matching_peaks['RT_Diff'] = abs(matching_peaks['Peak_RT'] - compound_rt)
# /var/folders/1j/7hbmv0v92x141ltlqxmr9dzw0000gn/T/ipykernel_48438/2042415455.py:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matching_peaks['RT_Diff'] = abs(matching_peaks['Peak_RT'] - compound_rt)
# Extracted 7752 compounds
# Found 41 chromatogram peaks
# Matched 562 compounds to peaks
#    Cpd     Formula     RT      Mass CAS_ID Source  Score Algorithm  \
# 0    1  C22H20N2O7  7.244  424.1283   None    FBF  80.84       FBF
# 1    2    C16H18N2  6.621  238.1489   None    FBF  59.55       FBF
# 2    3   C21H23NO5  7.790  369.1593   None    FBF  85.46       FBF
# 3    4    C10H15NO  4.411  165.1141   None    FBF  62.69       FBF
# 4    5  C21H24N2O2  4.437  336.1859   None    FBF  63.83       FBF
# 5    6    C18H20N2  4.281  264.1609   None    FBF  61.60       FBF
# 6    7  C15H22N2O2  3.943  262.1680   None    FBF  59.15       FBF
# 7    8    C14H8N2O  2.305  220.0624   None    FBF  60.43       FBF
# 8    9   C18H35NO2  6.491  297.2665   None    FBF  96.14       FBF
# 9   10      C8H17N  0.409  127.1362   None    FBF  86.17       FBF
#
#          Area Area_Pct Peak_Height
# 0   1655591.0      1.2    404359.0
# 1        None     None        None
# 2        None     None        None
# 3        None     None        None
# 4  34988729.0    25.39   6894655.0
# 5  65500642.0    47.53   8732868.0
# 6        None     None        None
# 7        None     None        None
# 8   4820751.0      3.5    758811.0
# 9        None     None        None
# Total compounds extracted: 7752
#
# Formula value counts:
# Formula
# C8H17NO       2
# C9H17NO3      2
# C22H20N2O7    1
# C4H7NO4       1
# C12H24N2O7    1
# Name: count, dtype: int64
#
# RT statistics:
# count    7752.000000
# mean       11.612538
# std         6.423298
# min         0.331000
# 25%         5.296000
# 50%        12.235000
# 75%        17.745000
# max        22.966000
# Name: RT, dtype: float64
# After filtering for areas : 562
#        Cpd      Formula     RT      Mass CAS_ID Source  Score Algorithm  \
# 824    827   C24H43N3O4  3.267  437.3214   None    FBF  55.54       FBF
# 5689  5692     C12H10O4  3.267  218.0567   None    FBF  71.58       FBF
# 5733  5736  C9H16ClN3O2  3.267  233.0922   None    FBF  50.22       FBF
# 5541  5544   C16H28N4O7  3.007  388.1948   None    FBF  93.81       FBF
# 5476  5479   C19H28N4O5  3.007  392.2022   None    FBF  65.66       FBF
#
#              Area Area_Pct Peak_Height
# 824   137818488.0    100.0   8741437.0
# 5689  137818488.0    100.0   8741437.0
# 5733  137818488.0    100.0   8741437.0
# 5541  135352463.0    98.21   8155244.0
# 5476  135352463.0    98.21   8155244.0
#
# Processing /Users/yitong/Documents/GitHub/shell_diaries/TRYING_OUT_MS_RESULTS/70425_shell6_Analysis.pdf...
# Warning: No chromatogram peaks found in /Users/yitong/Documents/GitHub/shell_diaries/TRYING_OUT_MS_RESULTS/70425_shell6_Analysis.pdf
#    Cpd     Formula      RT      Mass CAS_ID Source  Score Algorithm  Area  \
# 0    1  C20H24N2O2  19.813  324.1842   None    FBF  71.19       FBF  None
# 1    2  C20H26N2O2  15.345  326.1998   None    FBF  83.69       FBF  None
# 2    3   C21H23NO5   7.834  369.1604   None    FBF  63.43       FBF  None
# 3    4   C15H25NO4  13.421  283.1776   None    FBF  50.17       FBF  None
# 4    5  C35H40N4O3  22.515  564.3096   None    FBF  56.85       FBF  None
# 5    6   C20H29NO2  18.280  315.2179   None    FBF  70.01       FBF  None
# 6    7   C18H35NO2   6.509  297.2658   None    FBF  87.79       FBF  None
# 7    8      C8H17N  16.098  127.1361   None    FBF  86.89       FBF  None
# 8    9  C23H30N2O4  18.488  398.2222   None    FBF  71.50       FBF  None
# 9   10  C11H13ClN2  20.489  208.0781   None    FBF  50.70       FBF  None
#
#   Area_Pct Peak_Height
# 0     None        None
# 1     None        None
# 2     None        None
# 3     None        None
# 4     None        None
# 5     None        None
# 6     None        None
# 7     None        None
# 8     None        None
# 9     None        None
# Total compounds extracted: 4877
#
# Formula value counts:
# Formula
# C20H24N2O2     1
# C46H84NO14P    1
# C46H74NO14P    1
# C38H58NO12P    1
# C38H60NO13P    1
# Name: count, dtype: int64
#
# RT statistics:
# count    4877.000000
# mean       16.210611
# std         4.781741
# min         0.330000
# 25%        13.785000
# 50%        17.630000
# 75%        19.657000
# max        22.956000
# Name: RT, dtype: float64
# After filtering for areas : 0
# Empty DataFrame
# Columns: [Cpd, Formula, RT, Mass, CAS_ID, Source, Score, Algorithm, Area, Area_Pct, Peak_Height]
# Index: []
#
# Processing /Users/yitong/Documents/GitHub/shell_diaries/TRYING_OUT_MS_RESULTS/70425_shell7_Analysis.pdf...
# Warning: No chromatogram peaks found in /Users/yitong/Documents/GitHub/shell_diaries/TRYING_OUT_MS_RESULTS/70425_shell7_Analysis.pdf
#    Cpd     Formula      RT      Mass CAS_ID Source  Score Algorithm  Area  \
# 0    1  C20H24N2O2   8.412  324.1863   None    FBF  63.93       FBF  None
# 1    2   C21H23NO5   7.788  369.1588   None    FBF  75.10       FBF  None
# 2    3   C23H29NO6  17.431  415.2012   None    FBF  59.33       FBF  None
# 3    4  C21H24N2O2  21.900  336.1851   None    FBF  66.75       FBF  None
# 4    5   C20H29NO2  19.094  315.2182   None    FBF  53.81       FBF  None
# 5    6   C18H35NO2   6.515  297.2661   None    FBF  82.92       FBF  None
# 6    7  C28H38N2O4  21.459  466.2817   None    FBF  55.75       FBF  None
# 7    8      C8H17N  15.898  127.1360   None    FBF  86.70       FBF  None
# 8    9  C29H40N2O4  16.158  480.2991   None    FBF  62.21       FBF  None
# 9   10   C19H25NO2   6.957  299.1872   None    FBF  63.80       FBF  None
#
#   Area_Pct Peak_Height
# 0     None        None
# 1     None        None
# 2     None        None
# 3     None        None
# 4     None        None
# 5     None        None
# 6     None        None
# 7     None        None
# 8     None        None
# 9     None        None
# Total compounds extracted: 4873
#
# Formula value counts:
# Formula
# C9H15NO5        2
# C20H24N2O2      1
# C64H126NO10P    1
# C66H128NO11P    1
# C65H110NO10P    1
# Name: count, dtype: int64
#
# RT statistics:
# count    4873.000000
# mean       16.200280
# std         4.780128
# min         0.232000
# 25%        13.767000
# 50%        17.638000
# 75%        19.536000
# max        22.965000
# Name: RT, dtype: float64
# After filtering for areas : 0
# Empty DataFrame
# Columns: [Cpd, Formula, RT, Mass, CAS_ID, Source, Score, Algorithm, Area, Area_Pct, Peak_Height]
# Index: []

# %%
break
# Out:
#   Cell In[4], line 1
#     break
#     ^
# SyntaxError: 'break' outside loop

# %%
# Method 1: Direct from PDF
df = extract_compound_summary('MS_RESULTS/TINY_shell_Analysis.pdf')

# Display results
print(df.head(10))
print(f"\nTotal compounds extracted: {len(df)}")

# Save to CSV
df.to_csv('compound_summary.csv', index=False)

# Optional: Additional analysis
print("\nFormula value counts:")
print(df['Formula'].value_counts().head())

print("\nRT statistics:")
print(df['RT'].describe())

has_peak_df = df[~df['Area'].isna()]
has_peak_df
has_peak_df.sort_values(by='Area_Pct',ascending=False)

# %%
# Method 1: Direct from PDF
df = extract_compound_summary('MS_RESULTS/TINY_shell_Analysis.pdf')

# Display results
print(df.head(10))
print(f"\nTotal compounds extracted: {len(df)}")

# Save to CSV
df.to_csv('compound_summary.csv', index=False)

# Optional: Additional analysis
print("\nFormula value counts:")
print(df['Formula'].value_counts().head())

print("\nRT statistics:")
print(df['RT'].describe())

has_peak_df = df[~df['Area'].isna()]
has_peak_df
has_peak_df.sort_values(by='Area_Pct',ascending=False)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[55], line 2
#       1 # Method 1: Direct from PDF
# ----> 2 df = extract_compound_summary('MS_RESULTS/TINY_shell_Analysis.pdf')
#       4 # Display results
#       5 print(df.head(10))
#
# Cell In[49], line 123, in extract_compound_summary(pdf_path, rt_tolerance)
#     120 compounds = []
#     122 for page in pdf.pages:
# --> 123     text = page.extract_text()
#     124     full_text += text + "\n"
#     126     # Find the Compound Summary section
#
# File /opt/miniconda3/envs/radial_faces_env/lib/python3.8/site-packages/pdfplumber/page.py:548, in Page.extract_text(self, **kwargs)
#     547 def extract_text(self, **kwargs: Any) -> str:
# --> 548     return self.get_textmap(**tuplify_list_kwargs(kwargs)).as_string
#
# File /opt/miniconda3/envs/radial_faces_env/lib/python3.8/site-packages/pdfplumber/page.py:525, in Page._get_textmap(self, **kwargs)
#     523     defaults.update({"layout_height": self.height})
#     524 full_kwargs: Dict[str, Any] = {**defaults, **kwargs}
# --> 525 return utils.chars_to_textmap(self.chars, **full_kwargs)
#
# File /opt/miniconda3/envs/radial_faces_env/lib/python3.8/site-packages/pdfplumber/container.py:52, in Container.chars(self)
#      50 @property
#      51 def chars(self) -> T_obj_list:
# ---> 52     return self.objects.get("char", [])
#
# File /opt/miniconda3/envs/radial_faces_env/lib/python3.8/site-packages/pdfplumber/page.py:357, in Page.objects(self)
#     355 if hasattr(self, "_objects"):
#     356     return self._objects
# --> 357 self._objects: Dict[str, T_obj_list] = self.parse_objects()
#     358 return self._objects
#
# File /opt/miniconda3/envs/radial_faces_env/lib/python3.8/site-packages/pdfplumber/page.py:461, in Page.parse_objects(self)
#     459 def parse_objects(self) -> Dict[str, T_obj_list]:
#     460     objects: Dict[str, T_obj_list] = {}
# --> 461     for obj in self.iter_layout_objects(self.layout._objs):
#     462         kind = obj["object_type"]
#     463         if kind in ["anno"]:
#
# File /opt/miniconda3/envs/radial_faces_env/lib/python3.8/site-packages/pdfplumber/page.py:279, in Page.layout(self)
#     273 device = PDFPageAggregatorWithMarkedContent(
#     274     self.pdf.rsrcmgr,
#     275     pageno=self.page_number,
#     276     laparams=self.pdf.laparams,
#     277 )
#     278 interpreter = PDFPageInterpreter(self.pdf.rsrcmgr, device)
# --> 279 interpreter.process_page(self.page_obj)
#     280 self._layout: LTPage = device.get_result()
#     281 return self._layout
#
# File /opt/miniconda3/envs/radial_faces_env/lib/python3.8/site-packages/pdfminer/pdfinterp.py:997, in PDFPageInterpreter.process_page(self, page)
#     995     ctm = (1, 0, 0, 1, -x0, -y0)
#     996 self.device.begin_page(page, ctm)
# --> 997 self.render_contents(page.resources, page.contents, ctm=ctm)
#     998 self.device.end_page(page)
#     999 return
#
# File /opt/miniconda3/envs/radial_faces_env/lib/python3.8/site-packages/pdfminer/pdfinterp.py:1016, in PDFPageInterpreter.render_contents(self, resources, streams, ctm)
#    1014 self.init_resources(resources)
#    1015 self.init_state(ctm)
# -> 1016 self.execute(list_value(streams))
#    1017 return
#
# File /opt/miniconda3/envs/radial_faces_env/lib/python3.8/site-packages/pdfminer/pdfinterp.py:1027, in PDFPageInterpreter.execute(self, streams)
#    1025 while 1:
#    1026     try:
# -> 1027         (_, obj) = parser.nextobject()
#    1028     except PSEOF:
#    1029         break
#
# File /opt/miniconda3/envs/radial_faces_env/lib/python3.8/site-packages/pdfminer/psparser.py:609, in PSStackParser.nextobject(self)
#     601 """Yields a list of objects.
#     602
#     603 Arrays and dictionaries are represented as Python lists and
#    (...)
#     606 :return: keywords, literals, strings, numbers, arrays and dictionaries.
#     607 """
#     608 while not self.results:
# --> 609     (pos, token) = self.nexttoken()
#     610     if isinstance(token, (int, float, bool, str, bytes, PSLiteral)):
#     611         # normal token
#     612         self.push((pos, token))
#
# File /opt/miniconda3/envs/radial_faces_env/lib/python3.8/site-packages/pdfminer/psparser.py:527, in PSBaseParser.nexttoken(self)
#     525 while not self._tokens:
#     526     self.fillbuf()
# --> 527     self.charpos = self._parse1(self.buf, self.charpos)
#     528 token = self._tokens.pop(0)
#     529 log.debug("nexttoken: %r", token)
#
# File /opt/miniconda3/envs/radial_faces_env/lib/python3.8/site-packages/pdfminer/psparser.py:423, in PSBaseParser._parse_keyword(self, s, i)
#     422 def _parse_keyword(self, s: bytes, i: int) -> int:
# --> 423     m = END_KEYWORD.search(s, i)
#     424     if not m:
#     425         self._curtoken += s[i:]
#
# KeyboardInterrupt:

# %%
has_peak_df = df[~df['Area'].isna()]
has_peak_df
has_peak_df.sort_values(by='Area_Pct',ascending=False)
# Out:
#        Cpd       Formula     RT      Mass CAS_ID Source  Score Algorithm  \
# 824    827    C24H43N3O4  3.267  437.3214   None    FBF  55.54       FBF
# 5689  5692      C12H10O4  3.267  218.0567   None    FBF  71.58       FBF
# 5733  5736   C9H16ClN3O2  3.267  233.0922   None    FBF  50.22       FBF
# 5541  5544    C16H28N4O7  3.007  388.1948   None    FBF  93.81       FBF
# 5476  5479    C19H28N4O5  3.007  392.2022   None    FBF  65.66       FBF
# ...    ...           ...    ...       ...    ...    ...    ...       ...
# 225    226      C21H24O8  7.244  404.1475   None    FBF  94.95       FBF
# 5320  5323  C40H53N7O5S2  7.244  775.3564   None    FBF  70.65       FBF
# 5339  5342    C20H29N7O4  7.244  431.2305   None    FBF  86.31       FBF
# 5353  5356    C14H26N4O6  7.244  346.1823   None    FBF  69.61       FBF
# 0        1    C22H20N2O7  7.244  424.1283   None    FBF  80.84       FBF
#
#              Area Area_Pct Peak_Height
# 824   137818488.0    100.0   8741437.0
# 5689  137818488.0    100.0   8741437.0
# 5733  137818488.0    100.0   8741437.0
# 5541  135352463.0    98.21   8155244.0
# 5476  135352463.0    98.21   8155244.0
# ...           ...      ...         ...
# 225     1655591.0      1.2    404359.0
# 5320    1655591.0      1.2    404359.0
# 5339    1655591.0      1.2    404359.0
# 5353    1655591.0      1.2    404359.0
# 0       1655591.0      1.2    404359.0
#
# [562 rows x 11 columns]

# %%
break
# Out:
#   Cell In[52], line 1
#     break
#     ^
# SyntaxError: 'break' outside loop

# %%
# import pandas as pd
# import re
# import pdfplumber

# def extract_compound_summary(pdf_path):
#     """
#     Extract Compound Summary table from MassHunter Analysis Report PDF.
    
#     Parameters:
#     -----------
#     pdf_path : str
#         Path to the PDF file
        
#     Returns:
#     --------
#     pd.DataFrame
#         DataFrame containing the compound summary data
#     """
    
#     # Method 1: Using pdfplumber (recommended for tables)
#     with pdfplumber.open(pdf_path) as pdf:
#         compounds = []
        
#         for page in pdf.pages:
#             text = page.extract_text()
            
#             # Find the Compound Summary section
#             if "Compound Summary" in text:
#                 lines = text.split('\n')
                
#                 # Find where compound data starts
#                 start_idx = None
#                 for i, line in enumerate(lines):
#                     if re.match(r'^\d+\s+C\d+\s+H\d+', line):
#                         start_idx = i
#                         break
                
#                 if start_idx:
#                     # Parse each compound line
#                     for line in lines[start_idx:]:
#                         # Match pattern: number, formula, RT, Mass, optional CAS, Source, Scores
#                         match = re.match(
#                             r'^(\d+)\s+(C\d+\s+H\d+(?:\s+[A-Z][a-z]?\d*)*)\s+'
#                             r'([\d.]+)\s+([\d.]+)\s+'
#                             r'(?:([\d-]+)\s+)?'  # Optional CAS ID
#                             r'(\w+)\s+([\d.]+)\s+(\w+)',
#                             line
#                         )
                        
#                         if match:
#                             cpd_num = int(match.group(1))
#                             formula = match.group(2).replace(' ', '')
#                             rt = float(match.group(3))
#                             mass = float(match.group(4))
#                             cas_id = match.group(5) if match.group(5) else None
#                             source = match.group(6)
#                             score = float(match.group(7))
#                             algorithm = match.group(8)
                            
#                             compounds.append({
#                                 'Cpd': cpd_num,
#                                 'Formula': formula,
#                                 'RT': rt,
#                                 'Mass': mass,
#                                 'CAS_ID': cas_id,
#                                 'Source': source,
#                                 'Score': score,
#                                 'Algorithm': algorithm
#                             })
    
#     return pd.DataFrame(compounds)


# def extract_from_text(text_content):
#     """
#     Alternative method: Extract from already extracted text content.
#     Use this if you already have the PDF text extracted.
    
#     Parameters:
#     -----------
#     text_content : str
#         Text content from the PDF
        
#     Returns:
#     --------
#     pd.DataFrame
#         DataFrame containing the compound summary data
#     """
    
#     compounds = []
#     lines = text_content.split('\n')
    
#     # Find the Compound Summary section
#     in_compound_section = False
    
#     for line in lines:
#         if "Compound Summary" in line:
#             in_compound_section = True
#             continue
        
#         if in_compound_section:
#             # Match compound data lines
#             match = re.match(
#                 r'^(\d+)\s+(C\d+\s+H\d+(?:\s+[A-Z][a-z]?\d*)*)\s+'
#                 r'([\d.]+)\s+([\d.]+)\s+'
#                 r'(?:([\d-]+)\s+)?'  # Optional CAS ID
#                 r'(\w+)\s+([\d.]+)\s+(\w+)',
#                 line
#             )
            
#             if match:
#                 compounds.append({
#                     'Cpd': int(match.group(1)),
#                     'Formula': match.group(2).replace(' ', ''),
#                     'RT': float(match.group(3)),
#                     'Mass': float(match.group(4)),
#                     'CAS_ID': match.group(5),
#                     'Source': match.group(6),
#                     'Score': float(match.group(7)),
#                     'Algorithm': match.group(8)
#                 })
            
#             # Stop if we hit another section
#             elif line.strip() and not line.startswith('Cpd'):
#                 if compounds:  # Only stop if we've found some compounds
#                     break
    
#     return pd.DataFrame(compounds)

# %%
df = extract_compound_summary('/Users/yitong/Documents/GitHub/shell_diaries/MS_RESULTS/BIGMED_shell_Analysis.pdf')
df
# Out:
#        Cpd     Formula      RT      Mass CAS_ID Source  Score Algorithm
# 0        1  C20H26N2O2  21.951  326.1965   None    FBF  55.97       FBF
# 1        2   C21H23NO5   7.814  369.1589   None    FBF  76.93       FBF
# 2        3   C15H25NO4  10.803  283.1766   None    FBF  80.38       FBF
# 3        4   C14H8N2O2   0.933  236.0609   None    FBF  59.77       FBF
# 4        5  C35H40N4O3  18.131  564.3063   None    FBF  63.21       FBF
# ...    ...         ...     ...       ...    ...    ...    ...       ...
# 4766  4769    C29H52O8  10.258  528.3640   None    FBF  63.56       FBF
# 4767  4770     C29H44O  14.313  408.3407   None    FBF  56.25       FBF
# 4768  4771     C29H42O  17.093  406.3275   None    FBF  51.19       FBF
# 4769  4772    C29H42O2   9.140  422.3217   None    FBF  59.13       FBF
# 4770  4773     C29H40O  12.441  404.3053   None    FBF  51.98       FBF
#
# [4771 rows x 8 columns]

# %%
# Example usage:
if __name__ == "__main__":
    # Method 1: Direct from PDF
    df = extract_compound_summary('/Users/yitong/Documents/GitHub/shell_diaries/MS_RESULTS/BIGMED_shell_Analysis.pdf')
    
    # Method 2: From your provided text
    text = """
    [Your PDF text content here]
    """
    
    df = extract_from_text(text)
    
    # Display results
    print(df.head(10))
    print(f"\nTotal compounds extracted: {len(df)}")
    
    # Save to CSV
    df.to_csv('compound_summary.csv', index=False)
    
    # Optional: Additional analysis
    print("\nFormula value counts:")
    print(df['Formula'].value_counts().head())
    
    print("\nRT statistics:")
    print(df['RT'].describe())
